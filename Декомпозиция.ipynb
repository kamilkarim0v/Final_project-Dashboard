# %% [markdown]
# # Мобильное приложение "Ненужные вещи"

# %% [markdown]
# ## Описание проекта.

# %% [markdown]
# Мы работаем аналитиком в проекте, который содержит сервис "Ненужные вещи" - мобильное приложение по продаже вещей(«Ненужные вещи» — ваши ненужные вещи нужны кому-то другому!). В нем пользователи продают свои ненужные вещи, размещая их на доске объявлений.
#
# **Описание данных:**
#
# Датасет содержит данные о событиях, совершенных в мобильном приложении "Ненужные вещи".
#
# В датасете содержатся данные пользователей, впервые совершивших действия в приложении после 7 октября 2019 года.
#
# В нашем распоряжении есть 2 датасета:
#
# 1) mobile_dataset.csv содержит колонки:
#
#     - event.time — время совершения;
#     - event.name — название события;
#     - user.id — идентификатор пользователя.
#
# 2) mobile_sources.csv содержит колонки:
#
#     - userId — идентификатор пользователя;
#     - source — источник, с которого пользователь установил приложение.
#     Расшифровки событий:
#     - advert_open — открытие карточки объявления;
#     - photos_show — просмотр фотографий в объявлении;
#     - tips_show — пользователь увидел рекомендованные объявления;
#     - tips_click — пользователь кликнул по рекомендованному объявлению;
#     - contacts_show и show_contacts — пользователь нажал на кнопку "посмотреть номер телефона" на карточке объявления;
#     - contacts_call — пользователь позвонил по номеру телефона на карточке объявления;
#     - map — пользователь открыл карту размещенных объявлений;
#     - search_1 — search_7 — разные события, связанные с поиском по сайту;
#     - favorites_add — добавление объявления в избранное.
#
# На основании данных нужно извлечь инсайты, которые помогут нам стать лучшим приложением для продажи ненужных вещей.
#
# **Задачи:**
#
# - Выделить группы пользователей, которые различаются по метрикам:
#
#     1. retention rate,
#     2. время, проведённое в приложении,
#     3. частота действий,
#     4. конверсия в целевое действие — просмотр контактов.
#
#
# - Провести исследовательский анализ данных;
#
#
# - Сегментируйте пользователей на основе действий;
#
#
# - Проверьте статистические гипотезы:
#     1. *Некоторые пользователи установили приложение по ссылке из `yandex`, другие — из `google`. Проверьте гипотезу: две эти группы демонстрируют разную конверсию в просмотры контактов.*
#     2. *Сформулируйте собственную гипотезу. Дополните её нулевой и альтернативной гипотезами. Проведите статистический тест.*
#
#
# - Составить призентацию, дать рекомендации.
#
#
# - Составить дашборд:
#
# Дашборд делается после основного проекта, следующим заданием. Чтобы отправить дашборд, приложите в документ ссылку на файл. Выберите один из наборов:
#
# 1. Набор №1
#     1. Постройте диаграмму распределения количества событий по типу события
#     2. Добавьте индикатор количества пользователей
#     3. Добавьте фильтр дашборда по дате совершения события
# 2. Набор №2
#     1. Постройте диаграмму, отображающую количество событий по дням
#     2. Постройте гистограмму, отображающую количество пользователей, пришедших из разных источников
#     3. Добавьте фильтр дашборда по типу события

# %% [markdown]
# ## Шаг 1. Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# #### 1. Создаем рабочую среду (Импортирем библиотеки)

# %% [markdown]
# ####  2.Считываем данные из csv-файлов в датафреймы и сохраняем в переменные

# %% [markdown]
# #### 3. Изучаем общую информацию о полученных датафреймах

# %% [markdown]
# **на 1 шаге мы:**
#
# 1) импортировали библиотеки;
#
# 2) записали данные в датафрейм;
#
# 3) изучили общую информацию о полученном датафрейме.

# %% [markdown]
# ## Шаг 2. Подготовьте данные.

# %% [markdown]
# #### 1. Объедените датафреймы.

# %% [markdown]
# ####  2. Замените названия столбцов на удобные для вас.

# %% [markdown]
# ####  3. Проверьте пропуски и типы данных.

# %% [markdown]
# ####  4. Проверим данные на явные и неявные дубликаты.

# %% [markdown]
# #### 5. Добавьте вспомогательные столбцы(если нужны).

# %% [markdown]
# **на 2 шаге мы:**

# %% [markdown]
# ## Шаг 3. Ислледовательский анализ данных.

# %% [markdown]
# #### 1. retention rate

# %% [markdown]
# #### 2. время, проведённое в приложении.

# %% [markdown]
# #### 3. частота действий.

# %% [markdown]
# #### 4. конверсия в целевое действие — просмотр контактов.

# %% [markdown]
# **на 3 шаге мы:**

# %% [markdown]
# ## Шаг 4. Сегментация.

# %% [markdown]
# #### 1. Сегментация пользователей на основе событий(разделение на группы по определенному признаку).

# %% [markdown]
# #### 2. Выделить лучшие группы по retention rate.

# %% [markdown]
# #### 2. Выделить лучшие группы по времени, проведённом в приложении.

# %% [markdown]
# #### 2. Выделить лучшие группы по частоте действий.

# %% [markdown]
# #### 2. Выделить лучшие группы по конверсии в целевое действие — просмотр контактов.

# %% [markdown]
# ## Шаг 5. Проверка статичстических гипотез.

# %% [markdown]
# #### 1. Некоторые пользователи установили приложение по ссылке из yandex, другие — из google. Проверьте гипотезу: две эти группы демонстрируют разную конверсию в просмотры контактов.

# %% [markdown]
# #### 2. У пользователей, активных в вечернее время(1 из четырех групп (утренняя, дневная, вечерняя, ночная)) конверсия в целевое действие выше, чем у пользователей, актывных в дневное время.

# %% [markdown]
# ## Шаг 6. Общий вывод. Рекомендации.

# %% [markdown]
# ## Шаг 7. Презентация.

# %% [markdown]
# ## Шаг 8. Дашборд.
